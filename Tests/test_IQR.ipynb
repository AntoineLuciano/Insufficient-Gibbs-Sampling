# %%
from truncated import *
from IQR import *
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %load_ext autoreload
# %autoreload 2
# %load_ext line_profiler
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %% [markdown]
# # Normal distribution

# %%
med,IQR=2,1
N=1003
T=1000
Normal=Gibbs_med_IQR(T,N,med,IQR,std_prop_quantile=.01,distribution="cauchy",)
# Out:
# 100%|██████████| 1000/1000 [00:12<00:00, 79.96it/s]
# Acceptance rates of Quantile : Q 0 = 67.73%
# Q 1 = 69.03%
# Q 2 = 70.93%
# Acceptation rates MH : loc = 27.20% scale = 27.30%

# %%
scipy.stats.norm(loc=0,scale=1.4826/2).ppf(0.25)
# Out:
# -0.4999992518203553

# %%
Q=Normal["Q_sim"]
for i in range(Q.shape[1]):
    plt.plot(Normal["Q_sim"].T[-i])
    plt.show()

# %%
f,ax=plt.subplots(2,2,figsize=(10,5))

sns.kdeplot(Normal["chains"]["loc"],ax=ax[0,0])
ax[1,0].plot(Normal["chains"]["loc"])

sns.kdeplot(Normal["chains"]["scale"],ax=ax[0,1])
ax[0,1].axvline(1.4826/2,color="red")
ax[1,1].plot(Normal["chains"]["scale"])
